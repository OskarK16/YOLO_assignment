# %% [markdown]
# # **Homework assignment**
#
#
# > Oskar Krawczyk, AIML22 Group 3

# %% [markdown]
# ---
#
#
# As part of this homework assignment, we will go through topics covered in the past few days, specifically computer vision for object detection using single-stage detectors from YOLO (You Only Look Once) family. To do so, we will create a custom dataset based on the [DOTA OBB dataset](https://docs.ultralytics.com/tasks/obb#visual-samples$0). Then, we will consider multiple YOLO model variants, train them and eventually compare their results using various object detection metrics, including mAP, precision and recall. Interestingly, the problem we will be solving revolves around the Oriented Object Detection, that is instead of regular rectangles we might as well detect objects using their rotations which leads to a better fit and performance. With that being said, we can now proceed to Part 1.

# %% [markdown]
# In the following notebook, I split my solution into four separate sections - Part 1, 2, 3, 4 - which follow the convention used in the initial [Oriented_YOLO_Homework_Assignment.ipynb](https://www.dropbox.com/scl/fi/y56wdguadaxzws6yriqnc/Oriented_YOLO_Homework_Assignment.ipynb?rlkey=wo2qner3gzn78vwaqemz6ntd3&st=apcxg80s&e=1&dl=0$0) notebook. Each section includes the code as part of my solution as well as a brief explanation of certain concepts not mentioned during lectures/seminars. At the end of this notebook, I also denote resources used to complete and/or improve the final results and additional steps I have taken (beyond the required ones) to complete the notebook.
#
# ---

# %% [markdown]
# ## Part 1

# %% [markdown]
# In this section we first import all necessary libraries into a single cell. The reason is that in the future if someone tries to access the very same code, it is preferable to keep it in the single cell instead of imports scattered across the entire notebook. Then, we set up the notebook by specifying settings for plotting (matplotlib/seaborn), device and verify versions of libraries imported. Finally, we download the dataset, parse it and display its description (number of samples, classes, paths, ...).

# %%
# !rm -rf /content/DOTA-Demo-1 # Run if Roboflow connections has been lost/interrupted

# %% [markdown]
# The following cell is optional, nonetheless it is highly recommended (especially while running on Google Colab) since libraries like roboflow are not included in the standard setup. While debugging, removing -qq might be beneficial since this flag displays critical erros only.

# %%
# !pip install -qq ultralytics roboflow matplotlib pyyaml

# %% [markdown]
# #### Library imports

# %%
import os
import pathlib
import yaml
import colorsys
import random
import time
import cv2
import math

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.patheffects as path_effects
import seaborn as sns

import torch
from torch.utils.data import Dataset

import ultralytics
from ultralytics import YOLO
from roboflow import Roboflow
from typing import List

# %% [markdown]
# #### Notebook setup

# %% [markdown]
# Here, we configure the default setting for the notebook. First, we set the random seed to ensure the reproducibility of the results. Then, based on my preferences, we configure the default settings for matplotlib and seaborn to ensure consistent plotting. Finally, we display information regarding the imported libraries - if any methods change in future versions of these packages, this is a reference point.

# %%
random.seed(2026)
np.random.seed(2026)
torch.manual_seed(2026)

plt.rcParams["figure.figsize"] = (12, 12)
plt.rcParams["font.size"] = 12
plt.rcParams["axes.grid"] = False
plt.rcParams["figure.facecolor"] = "white"
plt.rcParams["axes.facecolor"] = "white"
plt.rcParams["figure.edgecolor"] = "white"
plt.rcParams["axes.edgecolor"] = "lightgray"
plt.rcParams["figure.dpi"] = 100

sns.set_theme(style = "whitegrid")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print("--- Notebook setup info ---")
print(f"Device:        {device}")
print(f"PyTorch:       {torch.__version__}")
print(f"OpenCV:        {cv2.__version__}")
print(f"Ultralytics:   {ultralytics.__version__}")
print(f"Numpy:         {np.__version__}")
# Out:
# --- Notebook setup info ---
# Device:        cuda
# PyTorch:       2.11.0+cu128
# OpenCV:        4.10.0
# Ultralytics:   8.4.104
# Numpy:         2.0.2

# %% [markdown]
# #### Introduce the dataset

# %% [markdown]
# Here, we first initialise the Roboflow API using a personal key and download the DOTA-demo dataset in the YOLOv8-OBB format (as suggested). Then we locate and parse the downloaded data.yaml configuration file. The reason why we modify and overwrite the path variable inside this file is that Roboflow often exports a default virtual path, which must be updated to our local path to ensure that YOLO can then correctly locate the images during training. Finally, we print out a detailed summary of the dataset's configuration, displaying the verified paths, the numnber of classes and the full list of class names.
#
# **Note**: It is required to use YAML in this notebook. [YAML](https://yaml.org) - "YAML Ain't Markup Language" is a human-friendly data serialisation language, used primarily as a configuration file. For more see the documentation.

# %%
PERSONAL_KEY = "rkdxr9QmPL4JSdG1T0KX" # if the personal key is no longer valid, you can generate it yourself and substitute mine.
roboflow = Roboflow(api_key = PERSONAL_KEY)

chosen_dataset = "dota-demo"
project = roboflow.workspace("rotated-object-detection").project(chosen_dataset)
dataset = project.version(1).download("yolov8-obb")

dataset_path = pathlib.Path(dataset.location)
yaml_path = dataset_path / "data.yaml"
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
with open(yaml_path, "r") as file:
    data_config = yaml.safe_load(file)

data_config["path"] = str(dataset_path.resolve())
with open(yaml_path, "w") as file:
    yaml.safe_dump(data_config, file)

print("Dataset - DOTA OBB - has been configured successfully.\n")

print("--- Dataset information ---")
print(f"Main path:                {data_config["path"]}")
print(f"Train dataset path:       {data_config["train"]}")
print(f"Validation dataset path:  {data_config["val"]}")
print(f"Test dataset path:        {data_config["test"]}")
print(f"Number of classes:        {len(data_config["names"])}")

print()

print("Classes in the dataset")
for i in range(len(data_config["names"])):
    print(f"{i}: {data_config['names'][i]}")
# Out:
# Dataset - DOTA OBB - has been configured successfully.
#
# --- Dataset information ---
# Main path:                /content/DOTA-Demo-1
# Train dataset path:       train/images
# Validation dataset path:  valid/images
# Test dataset path:        test/images
# Number of classes:        5
#
# Classes in the dataset
# 0: harbor
# 1: large-vehicle
# 2: plane
# 3: ship
# 4: small-vehicle

# %% [markdown]
# ## Part 2

# %% [markdown]
# In this section we define the DOTAOBBDataset, a custom dataset class inheriting from torch Dataset to handle Oriented Bounding Boxes data imported in Part 1. The class is equipped with multiple methods to properly process and display the data. In particular, our goal is to define the methods to properly pair images, convert YOLO's normalised coordinates (more on that in the next cell) into drawable pixel coordinates and create a visualisation for the rotated boxes. Finally, we instantiate the datasets for the train, validation and test samples and summarise their structures.

# %% [markdown]
# #### Examine structure

# %% [markdown]
# Before we create the dataset, we shall examine the structure of the downloaded data. We have already seen in the previous part its path and number of classes. Now, we are interested in its format and images' resolution.

# %%
sample_dataset = pathlib.Path(dataset_path / "train" / "images")

sample_images = []
for root, dirs, files in os.walk(sample_dataset):
    for file in files:
        if file.endswith(".jpg") or file.endswith(".png"):
            sample_images.append(os.path.join(root, file))

sample_image = sample_images[0]

extracted_image = cv2.imread(sample_image)
image = cv2.cvtColor(extracted_image, cv2.COLOR_BGR2RGB)

sample_height = image.shape[0]
sample_width = image.shape[1]
sample_channels = image.shape[2]


print("--- Sample summary ---\n")
print(f"Height:     {sample_height}")
print(f"Width:      {sample_width}")
print(f"Channels:   {sample_channels}")
# Out:
# --- Sample summary ---
#
# Height:     640
# Width:      640
# Channels:   3

# %%
sample_image_path = pathlib.Path(sample_image)
label_file = f"{sample_image_path.stem}.txt"

sample_label_path = dataset_path / "train" / "labels" / label_file

entry = {}
with open(sample_label_path, "r") as file:
    lines = file.readlines()

    for line in lines[:1]:
        line = line.strip()
        parts = line.split()

        entry["class_id"] = int(parts[0])
        coordinates = [float(x) for x in parts[1:9]]

        for i in range(4):
            entry[f"x{i+1}"] = coordinates[2 * i]
            entry[f"y{i+1}"] = coordinates[2 * i + 1]

        entry["class_name"] = data_config["names"][entry["class_id"]]

print(entry)
# Out:
# {'class_id': 3, 'x1': 0.5018782875000001, 'y1': 0.5990579921875001, 'x2': 0.4614254412883664, 'y2': 0.5945293972193942, 'x3': 0.46055597343750004, 'y3': 0.6022961437500001, 'x4': 0.5010088196491338, 'y4': 0.6068247387181059, 'class_name': 'ship'}

# %% [markdown]
# We can see that all images in the dataset (verified) are of size 640x640 with 3 colour channels. Each image has a corresponding label in the form of a list of proper annotations containing information about the class of an object and its bounding box. Furthermore, each coordinate is normalised to the range of [0, 1] - percantage of image's width/height.

# %% [markdown]
# #### Create Dataset

# %% [markdown]
# **Note**: We have just seen that in this YOLO dataset, bounding box coordinates are saved as normalised values (% between 0 and 1). Therefore to figure out where the pixel actually is, we have to multiply the percentage by the actual width of the image (the same applies to its height and y position). The coordinates on the other hand are stored in the [x1, y1, x2, y2, x3, y3, x4, y4] manner.

# %%
class DOTAOBBDataset(Dataset):
    '''
    Custom dataset class for handling Oriented Bounding Box data, speficially designed
    for YOLO-OBB formats and DOTA datasets.
    '''

    def __init__(self, images_dir: str, labels_dir: str, class_names: List[str], transform = None):
        '''
        Initialises a new instance of the DOTAOBBDataset class.

        Args:
            images_dir: Path to the directory containing the images.
            labels_dir: Path to the directory containing the labels.
            class_names: List of class names.
            transform: Optional transformation to be applied to the images.
        '''

        super().__init__()
        self.images_dir = pathlib.Path(images_dir)
        self.labels_dir = pathlib.Path(labels_dir)

        self.class_names = class_names
        self.transform = transform
        self.num_classes = len(class_names)

        image_files = []
        for root, dirs, files in os.walk(images_dir):
            for file in files:
                if file.endswith(".jpg") or file.endswith(".png"):
                    image_files.append(os.path.join(root, file))

        image_files = sorted(image_files)

        self.samples = []
        for image_path in image_files:
            temp_path = self.labels_dir / f"{pathlib.Path(image_path).stem}.txt"
            self.samples.append((image_path, temp_path))


    def __len__(self):
        '''
        Returns the number of samples in the dataset.
        '''

        return len(self.samples)

    def __getitem__(self, index: int):
        '''
        Retrieves a sample from the dataset based on the given index.

        Args:
            index: Index of the sample to retrieve.

        Returns:
            A dictionary containing the image, its annotations, its path and its size.
        '''

        image_path, label_path = self.samples[index]

        extracted_image = cv2.imread(image_path)
        image = cv2.cvtColor(extracted_image, cv2.COLOR_BGR2RGB)

        image_height, image_width = image.shape[0], image.shape[1]

        annotations = self.load_obb_annotations(label_path, image_width, image_height)

        if self.transform:
            image = self.transform(image = image)

        packed_image = {"image": image, "annotations": annotations, "image_path": image_path, "image_size": (image_height, image_width)}
        return packed_image

    def __str__(self):
        '''
        Returns a string representation of the dataset. In particular, displays statistics of the dataset
        such as number of classes, images and names of all classes.
        '''

        dataset_name = self.images_dir.parent.name

        statistics = (
            "----------------------------------------------\n"
            "\n"
            f"Dataset: \033[1m{dataset_name}\033[0m\n"
            f"Number of classes: {self.num_classes}\n"
            f"Number of images: {len(self.samples)}\n"
            f"Classes: {', '.join(self.class_names)}\n"
            "\n"
            "----------------------------------------------"
        )

        return statistics


    def load_obb_annotations(self, label_path: pathlib.Path, img_w: int, img_h: int):
        '''
        Reads YOLO OBB formatted text files and scales normalised coordinates to pixel coordinates.

        Args:
            label_path: Path to the label file.
            img_w: Width of the image.
            img_h: Height of the image.

        Returns:
            annotations: a list of dictionaries, where each dictionary contains details
            for a single bounding box (class_id, class_name, coordinates, normalised coordinates, pixel coordinates)
        '''

        with open(label_path, "r") as file:
            lines = file.readlines()

        annotations = []
        for line in lines:
            line = line.strip()

            if not line:
                continue

            parts = line.split()
            class_id = int(parts[0])
            coordinates = [float(x) for x in parts[1:9]]

            normalised_coordinates = []
            for i in range(4):
                x = coordinates[2 * i] * img_w
                y = coordinates[2 * i + 1] * img_h
                normalised_coordinates.append([x, y])

            annotations.append({
                "class_id": class_id,
                "class_name": self.class_names[class_id],
                "obb_coords": coordinates,
                "pixel_coords": normalised_coordinates
            })

        return annotations

    def visualise_sample(self, index: int, figsize: tuple = (12, 8)):
        '''
        Plots an image from the dataset and overlays its oriented bounding boxes.

        Args:
            index: Index of the sample to be plotted.
            figsize: Size of the figure.
        '''

        sample_data = self.__getitem__(index)

        if torch.is_tensor(sample_data["image"]):
            image = sample_data["image"].numpy().transpose((1, 2, 0))
        else:
            image = sample_data["image"]

        fig, ax = plt.subplots(figsize = figsize)
        fig.suptitle("Sample image")
        ax.imshow(image)

        for annotation in sample_data["annotations"]:
            class_idx = annotation["class_id"]
            class_name = annotation["class_name"]
            obb_coords = annotation["obb_coords"]
            pixel_coords = annotation["pixel_coords"]

            extracted_coordinates = np.array([pixel_coords]).reshape(4, 2)
            closed_polygon = np.vstack([extracted_coordinates, extracted_coordinates[0]])

            colour = self.get_class_colour(class_idx)

            ax.plot(closed_polygon[:, 0], closed_polygon[:, 1], color = colour, linewidth = 1)
            ax.fill(closed_polygon[:, 0], closed_polygon[:, 1], color = colour, alpha = 0.3)
            ax.text(pixel_coords[0][0], pixel_coords[0][1], class_name, color = "white", fontsize = 10,
                    bbox = dict(facecolor = colour, edgecolor = "none", alpha = .8, pad = 2.0),
                    path_effects = [path_effects.withStroke(linewidth = .4, foreground = "white")])

        plt.title(f"{index}: {pathlib.Path(sample_data["image_path"]).name}")
        plt.axis(False)
        plt.tight_layout()
        plt.show()


    def get_class_colour(self, class_idx: int):
        '''
        Generates a distinct colour for a given class index using the golden ratio
        in the HSV colour space to ensure visual separation between classes.
        See references for more.

        Args:
            class_idx: Index of the class.

        Returns:
            A tuple representing the colour in RGB format.
        '''

        if not hasattr(self, "_color_cache"):
            self._color_cache = {}

        if class_idx in self._color_cache:
            return self._color_cache[class_idx]

        golden_ratio = (1 + math.sqrt(5)) / 2.0
        hue = (class_idx * golden_ratio) % 1.0
        saturation = 1.0
        value = 1.0

        red, green, blue = colorsys.hsv_to_rgb(hue, saturation, value)
        out_colour = (red, green, blue, 1.0)

        self._color_cache[class_idx] = out_colour
        return out_colour

# %% [markdown]
# #### Split into train/test/valid datasets

# %% [markdown]
# We now need to retrieve the list of all classes (their names) to pass it as an argument to create instances of our dataset. We then create train, test and validation datasets to later show their descriptions - statistics including number of samples and classes.

# %%
class_names = list(data_config["names"].values())

train_dataset = DOTAOBBDataset(dataset_path / "train" / "images", dataset_path / "train" / "labels", class_names)
test_dataset = DOTAOBBDataset(dataset_path / "test" / "images", dataset_path / "test" / "labels", class_names)
valid_dataset = DOTAOBBDataset(dataset_path / "valid" / "images", dataset_path / "valid" / "labels", class_names)

# %%
print("Datasets descriptions\n")

print(train_dataset)
print(test_dataset)
print(valid_dataset)
# Out:
# Datasets descriptions
#
# ----------------------------------------------
#
# Dataset: train
# Number of classes: 5
# Number of images: 40
# Classes: harbor, large-vehicle, plane, ship, small-vehicle
#
# ----------------------------------------------
# ----------------------------------------------
#
# Dataset: test
# Number of classes: 5
# Number of images: 6
# Classes: harbor, large-vehicle, plane, ship, small-vehicle
#
# ----------------------------------------------
# ----------------------------------------------
#
# Dataset: valid
# Number of classes: 5
# Number of images: 12
# Classes: harbor, large-vehicle, plane, ship, small-vehicle
#
# ----------------------------------------------

# %% [markdown]
# It is apparent that we are dealing with a very small dataset containing only 40 training samples, 12 validation samples and 6 test samples. With that being said, now it is important to examine the number of each class in the aforementioned sets as this can significantly impact the training and testing processes. Specifically while dealing with a limited dataset (when it comes to the number of samples) class imbalace might cause unsatisfying results. If the data is not evenly distributed, the model might overfit to the highly represented classes while failing to learn the features of underrepresented ones. Furthermore, if the splits are not stratified, a specific class might be entirely absent from one of the datasets, making it difficult for the model to properly learn. We will investigate this problem further in Part 4.

# %%
def count_instances(labels_dir: pathlib.Path, class_names: List[str], counting_dict: dict):
    '''
    Iterates through label files to count the number of instances of each class.

    Args:
        labels_dir: Path to the directory containing label files.
        class_names: List of class names.
        counting_dict: Dictionary to store the count of instances for each class.
    '''

    for label_file in labels_dir.glob("*.txt"):
        with open(label_file, "r") as file:
            lines = file.readlines()
            for line in lines:
                line = line.strip()
                if line:
                    class_id = int(line.split()[0])
                    class_name = class_names[class_id]
                    if class_name in counting_dict:
                        counting_dict[class_name] += 1

# %%
train_counter = {class_name: 0 for class_name in class_names}
test_counter = {class_name: 0 for class_name in class_names}
valid_counter = {class_name: 0 for class_name in class_names}

count_instances(train_dataset.labels_dir, class_names, train_counter)
count_instances(test_dataset.labels_dir, class_names, test_counter)
count_instances(valid_dataset.labels_dir, class_names, valid_counter)

distributed_classes = pd.DataFrame({"Train": pd.Series(train_counter), "Test": pd.Series(test_counter), "Validation": pd.Series(valid_counter)})

ax = distributed_classes.plot(kind = "bar", width = 0.8, figsize = (8, 6), color = ["#FF9999", "#FF99FF", "#99FF99"])
plt.title("Number of instances of each class")
plt.xlabel("Class")
plt.ylabel("Number of instances")
plt.tight_layout()
plt.show()

# %% [markdown]
# With that being said, if we take a look at the bar chart above, it is clear that some clases are highly underrepresented in our dataset, in particular take a look at ship or large_vehicles which are really close to 0 in the test and validation dataset.

# %% [markdown]
# #### Investigate the results

# %% [markdown]
# Here, we display three randomly sampled images and their corresponding labels, that is classified bounded objects. We use a large scale (figsize = (8, 8)) on purpose to see the bounding boxes of even small objects well.

# %%
random_samples = [random.randint(0, 39) for _ in range(3)]

for i in random_samples:
    train_dataset.visualise_sample(i, figsize = (8, 8))

# %% [markdown]
# ## Part 3

# %% [markdown]
# In this section we perform models' training on the dataset implemented in Part 2. In particular, we select three various YOLO models:
#
# *   YOLO11n
# *   YOLOv8n
# *   YOLOv8m
#
# Each of these models is characterised by its parameters. Specifically, according to the official documentation, YOLO11n and YOLOv8n belong to so-called nano YOLO family (~3 million parameters). On the other hand, YOLOv8m belongs to so-called medium YOLO family (\~26 million parameters) and the model itself shares the same foundational architecture as YOLOv8n, yet scales the network significantly deeper. Since it is rather beyond this notebook's scope and the information above should be enough, YOLO11n's efficiency is mostly based on the use of [attention mechanism](https://arxiv.org/html/2410.17725v1) while YOLOv8 is characterised by anchor-free split detection head, meaning that it predicts the centre of an object directly rather than relying on predefined anchor boxes as it was the case in the initial YOLO variant models. Sources to the information provided here: [YOLOv8](https://docs.ultralytics.com/models/yolov8#key-features-of-yolov8), [YOLO11n](https://docs.ultralytics.com/models/yolo11#overview).
#
# Finally, we set main hyperparameters (see below) and based on that we perform training of each model while keeping track of various metrics (mainly mAP). At the end we compare training time of each model.

# %% [markdown]
# #### Training configuration

# %% [markdown]
# We first create a directory for the results obtained throughout training. Then we set hyperparameters and set config of the models which will be trained.

# %%
results_dir = pathlib.Path("./trained_models")
results_dir.mkdir(exist_ok = True)

EPOCHS = 30
BATCH_SIZE = 8
IMAGE_SIZE = 1024

models_config = {
    "yolo11n-obb": {
        "model_name": "yolo11n-obb.pt",
        "description": "YOLO11n",
        "save_dir": results_dir / "yolo11n-obb"
    },
    "yolov8n-obb": {
        "model_name": "yolov8n-obb.pt",
        "description": "YOLO8n",
        "save_dir": results_dir / "yolo8n-obb"
    },
    "yolov8m-obb": {
        "model_name": "yolov8m-obb.pt",
        "description": "YOLO8m",
        "save_dir": results_dir / "yolo8m-obb"
    }
}

# %% [markdown]
# #### Training and outcomes

# %% [markdown]
# We perform the training loop for each model. To do so, we use the config saved in the cell above. We measure the time of each model's training and then we save the results. Then, we perform initial comparison of each model's result (we will develop it further in Part 4). It is worth noting that OBB differ in architecture compared to standard/initial YOLO models since now we are dealing with "directed" by an angle $\Theta$. Therefore now our models have to predict not only [x, y, h, w], but also [x, y, h, w, $\theta$] or simply all four corners of the bounding box. It is also worth noting that while dealing with OBB problems, the standard IoU calculation should not be performed since standard IoU considers axis-aligned bounding boxes, ignoring the potential orientation of hte objects. Instead other methods are applied, especially [Probabilistic IoU](https://ieeexplore.ieee.org/document/10382963) to take the rotations and its matching into consideration. For more see the documentation.

# %%
training_results = {}

for model_key, config in models_config.items():
    model = YOLO(config["model_name"])

    start_time = time.time()

    results = model.train(
        data = str(yaml_path),
        epochs = EPOCHS,
        imgsz = IMAGE_SIZE,
        batch = BATCH_SIZE,
        project = str(results_dir),
        name = model_key,
        exist_ok = True,
        verbose = False,
    )

    end_time = time.time()
    sum_time = end_time - start_time

    training_results[model_key] = {
        "training_time": sum_time,
        "results": results,
        "weights_path": results_dir / model_key / "weights" / "best.pt"
    }
# Out:
# Ultralytics 8.4.104 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %% [markdown]
# I have performed multiple training cycles over the dataset with various parameters, especially varying number of epochs, image resolutions and transformations of training samples. After careful examination, it turned out that the best results have been achieved by the model with parameters above.
#
# Specficially, with the same models and comparable training time, I managed to achieve the results of at least ~0.40 mAP on each model, with ~0.50 mAP on YOLOv8m.

# %% [markdown]
# The above-mentioned results are not entirely surprising. Once again, it should be noted that we are working with a very small dataset - 40 training samples and only 12 validation samples. It is therefore no wonder that the results are not for example in the range of 0.70+ mAP, since training on such a small dataset and with low-parameter models like those from the nano YOLO family prevents us from achieving such high scores. The changes I made to obtain these results stemmed primarily from intuitive reasoning and experimentations. Note that if we were to work with images at a size of 640, we would significantly compress the resolution of our images. In this scenario, when dealing with models based on satellite images, even the human eye might struggle to spot cars from a bird's-eye view in low-resolution images. Hence, increasing the resolution to 1024 while decreasing number of epochs (since above this number, the training curve flattened), significantly improved the obtained results presented above.
#
# The question that might arise is whether increasing the resolution from original 640 to 1024 is a good practice. I see it this way: increasing the input resolution to 1024 preserves the main (spatial) features of tiny objects during the network's compression, therefore boosting mAP. However, this improvement comes at the cost of higher VRAM usage during training which requires other parameters (like batch size) to adjust to the new setting. That is why I believe that in our case it is beneficial to increase this size to 1024.

# %%
print("Finished training - Models trained successfully.\n")

for model_key, res in training_results.items():
    print(f"{model_key}: {round(res['training_time']/60.0, 2)} minutes")
# Out:
# Finished training - Models trained successfully.
#
# yolo11n-obb: 2.4 minutes
# yolov8n-obb: 2.03 minutes
# yolov8m-obb: 8.23 minutes

# %% [markdown]
# As it has already been mentioned in the brief explanation of each model, it is expected that the training time of nano models will be significantly lower than the medium ones. When it comes to nano models, the differences between the training time might have been caused by multiple factors, including the use of spatial attention mechanism in YOLO11n while YOLO8 standard conv blocks, or the fact that in detail, YOLOv8N has roughly 3.2 million parameters while YOLO11n about 2.6 million parameters.

# %% [markdown]
# **Further note**: At the end I also experimented with various other parameters included in YOLO models' training loops, including mosaic, mixups and merging methods. Although it increased the result by a fraction of 0.1, it caused the training to take more time, especially in the medium family models. Therefore, I decided to stay with parameters defined above.

# %% [markdown]
# ## Part 4

# %% [markdown]
# In this section, we move to the very last part of the solution - evaluation and visualisation. We will first load all the trained models and in the upcoming parts we will be able to see the results achieved by each model on our custom dataset.

# %% [markdown]
# #### Load trained models above

# %% [markdown]
# First, we need to load the models we actually used throughout training so that we can evaluate their performance.

# %%
trained_models = {}
for model_key, result in training_results.items():
    temp_path = pathlib.Path("runs/obb/trained_models") / model_key / "weights" / "best.pt"
    trained_models[model_key] = YOLO(temp_path)

# %% [markdown]
# #### Evaluation

# %% [markdown]
# We go through all models and calculate finals results, that is metrics for the corresponding model. We save them in evaluation_results from which it will be used in the further performance analysis.

# %%
evaluation_results = {}
map_results = {}

EPSILON = 1e-10

for model_key, model in trained_models.items():
    start_time = time.time()

    metrics = model.val(data = str(yaml_path), split = "test", verbose = False)

    end_time = time.time()
    total_time = end_time - start_time

    precision = metrics.box.mp
    recall = metrics.box.mr
    f1_score = 2 * (precision * recall) / (precision + recall + EPSILON) # using metrics.box.f1 would return an array, therefore we calculate it manually.

    map50 = metrics.box.map50
    map50_95 = metrics.box.map

    evaluation_results[model_key] = {
        "time": total_time,
        "precision": precision,
        "recall": recall,
        "f1_score": f1_score,
        "map50": map50,
        "map50_95": map50_95
    }

    classes = metrics.box.ap_class_index
    ap_50_class = metrics.box.ap50

    class_ap = {}
    for (index, ap) in zip(classes, ap_50_class):
        name = class_names[index]
        class_ap[name] = ap

    evaluation_results[model_key]["class_ap"] = class_ap
    map_results[model_key] = class_ap # solely to heatmap
# Out:
# Ultralytics 8.4.104 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11n-obb summary (fused): 110 layers, 2,654,698 parameters, 0 gradients, 6.6 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1152.6±368.7 MB/s, size: 50.3 KB)
# val: Scanning /content/DOTA-Demo-1/valid/labels.cache... 12 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 12/12 3.9Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.6it/s 0.6s
#                    all         12        309      0.446      0.425      0.426      0.263
# Speed: 1.1ms preprocess, 13.5ms inference, 0.0ms loss, 3.3ms postprocess per image
# Results saved to /content/runs/obb/val-4
# Ultralytics 8.4.104 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLOv8n-obb summary (fused): 82 layers, 3,078,194 parameters, 0 gradients, 8.3 GFLOPs
# ...

# %% [markdown]
# #### Metrics summary

# %% [markdown]
# Now, we shall display in the form of a table all statistics achieved for each model. These statistics we have already seen in the training phase, therefore the reulsts obtained are just summary of the previous step.

# %%
summary_data = {
    model: {k: v for k, v in metrics.items() if k != "class_ap"}
    for model, metrics in evaluation_results.items()
}

summary_df = pd.DataFrame(summary_data).T
display(summary_df.round(3))
# Out:
#               time  precision  recall  f1_score  map50  map50_95
# yolo11n-obb  7.481      0.446   0.425     0.435  0.426     0.263
# yolov8n-obb  4.030      0.810   0.396     0.532  0.381     0.244
# yolov8m-obb  8.885      0.529   0.682     0.596  0.512     0.290

# %% [markdown]
# #### Model comparison - bar chart

# %%
metrics_used = ["map50", "map50_95", "precision", "recall", "f1_score", "time"]
fig, axes = plt.subplots(3, 2, figsize = (10, 10))
fig.suptitle("Model performance comparison")

axes = axes.flatten()
colours_list = ["#CCFF99", "#FFFF99", "#99FF99"]

for idx, metric in enumerate(metrics_used):
    ax = axes[idx]
    values = summary_df[metric]
    models = summary_df.index

    bars = ax.bar(models, values, color = colours_list[:len(models)])
    ax.set_title(metric)

    for bar in bars:
        y = bar.get_height()
        ax.text(bar.get_x() + bar.get_width() / 2, y, f"{y:.2f}", ha = "center", va = "bottom")

plt.tight_layout()
plt.show()

# %% [markdown]
# It has already been described and it will be summarised in the Summary at the end of the notebook, nonetheless we can clearly see that the leading model is the one from medium family. We have already seen potential reasons for such occurrence, but given the bar charts it is apparent that most statistics confirm our initial observations through models' architecture and training performance.

# %% [markdown]
# #### Model comparison - heatmap

# %%
heatmap_data = pd.DataFrame(map_results)

sns.heatmap(heatmap_data, annot = True, cmap = "viridis")
plt.xlabel("Models")
plt.ylabel("Classes")
plt.show()

# %% [markdown]
# The reason why we obtain 0 in some cases, especially large vehicles has already been explained during the structure analysis. Here we can clearly see that it actually impacts our results obtained since some classes are not present in test/valid datasets or their appearance is significantly limited.

# %% [markdown]
# #### Plot predictions comparison

# %%
def plot_prediction_comparison(models, image_paths):
    '''
    Plotting predicted OBB for given sample images.

    Args:
        models: dictionary containing trained OBB models.
        image_paths: image paths to selected images.
    '''

    num_images = len(image_paths)
    num_models = len(models)

    fig, axes = plt.subplots(num_images, num_models)

    for i, image_path in enumerate(image_paths):
        for j, (model_name, model) in enumerate(models.items()):
            ax = axes[i, j]

            results = model.predict(source = str(image_path), imgsz = 1024, conf = 0.25)
            annotated_image = results[0].plot()
            annotated_image = cv2.cvtColor(annotated_image, cv2.COLOR_BGR2RGB)

            ax.imshow(annotated_image)
            ax.set_title(model_name)
            ax.axis("off")

    plt.tight_layout()
    plt.show()

# %%
sample_images = dataset_path / "test" / "images"
all_images = list(map(str, list(sample_images.glob("*"))))

samples = random.sample(all_images, 3)

plot_prediction_comparison(trained_models, samples)
# Out:
# image 1/1 /content/DOTA-Demo-1/test/images/P1144_png.rf.63ca3c72d4bebb446ab0aec2eac229e8.jpg: 640x640 2 planes, 25.9ms
# Speed: 3.0ms preprocess, 25.9ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DOTA-Demo-1/test/images/P1144_png.rf.63ca3c72d4bebb446ab0aec2eac229e8.jpg: 640x640 2 planes, 7.8ms
# Speed: 1.5ms preprocess, 7.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DOTA-Demo-1/test/images/P1144_png.rf.63ca3c72d4bebb446ab0aec2eac229e8.jpg: 640x640 2 planes, 38.2ms
# Speed: 1.5ms preprocess, 38.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/DOTA-Demo-1/test/images/P1114_png.rf.262ab0ab30e759fc48242e58d4d07dfd.jpg: 640x640 5 planes, 9.5ms
# Speed: 1.6ms preprocess, 9.5ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# ...

# %% [markdown]
# We can see that in most samples all models predict the images well. Clearly, the left-most models tends to place more than one prediction on certain objects which might be caused by it's parametric nature described above. Specifically, the classes it is mainly struggling with are the ones missing in the datasets which might be a potential justification of such problems.

# %%
def create_radar_char(evaluation_results):
  '''
  Generates a radar chart to compare the metrics used across the models.

  Args:
      evaluation_results: dictionary containing evaluation results for each model.
  '''

  metrics_used = ["map50", "map50_95", "precision", "recall", "f1_score"]
  num_metrics = len(metrics_used)

  angles = np.linspace(0, 2 * np.pi, num_metrics, endpoint = False).tolist()
  angles += angles[:1]

  fig, ax = plt.subplots(figsize = (6, 6), subplot_kw = {"projection": "polar"})

  for model_name, metrics in evaluation_results.items():
    values = [metrics[metric] for metric in metrics_used]
    values += values[:1]

    ax.plot(angles, values, linewidth = 2, label = model_name)
    ax.fill(angles, values, alpha = 0.2)

  ax.set_thetagrids(np.degrees(angles[:-1]), labels = metrics_used)
  ax.set_title("Model performance comparison", y = 1.1)
  ax.legend(loc = "upper right", bbox_to_anchor = (1.3, 1.2))

  plt.show()

# %%
create_radar_char(evaluation_results)

# %% [markdown]
# ## Summary

# %% [markdown]
# We have gone through the whole pipeline of computer vision object detection - from downloading the dataset, through creating a custom dataset class, all the way to training and evaluation. The last question to answer is: "Which model is the best and why?" and the best answer would probably be: "it depends". Whether it is model parameters, training time, number of samples and metrics we do care about, the answer might vary. If we were to focus solely on the dataset above, without any changes to the dataset being made, the best performace has been achieved by the model from the medium family - YOLOv8m, which as it has already been described is not surprising given for example the number of parameters and training settings.
#
# In my solution I have implemented all required steps, but also used various other methods throughout - e.g. custom colour method, dataset structure analysis, in-depth analysis of missing classes with brief description of potential solutions, many parameters used in the training loop and their potential impact on the achieved results. If there are any further questions regarding the notebook, I would be happy to answer them all.
#
# In the future the project might be developed further by introducing a larger dataset, various other YOLO models (e.g. more parameters) and further investigation of hyperparameters while tuning previous two methods.

# %% [markdown]
# ## References

# %% [markdown]
# Throughout the notebook (and while studying) I have used the following resources:
#
#
# *   YOLO original paper: https://arxiv.org/pdf/1506.02640$0
# *   Roboflow dataset documentation: https://docs.roboflow.com/datasets/adding-data#python-sdk$0
#
#
# *   Python documentation: https://docs.python.org/3.6/library/typing.html$0
# *   Class colours method: https://medium.com/@yamini1020.yanamala/the-art-and-science-of-color-creating-stunning-ui-palettes-6aea0a1c13b1$0
#
# * Golden ratio in colours: https://medium.com/@winwardo/simple-non-repeating-colour-generation-6efc995832b8$0
#
# ---

# %% [markdown]
# ![logo_lg.svg](data:image/svg+xml;base64,...)
